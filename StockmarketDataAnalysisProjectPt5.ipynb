# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %% [markdown]
# # from udemy -- outdated
# from pandas.io.data import DataReader

# %%
from pandas_datareader.data import DataReader

# %%
from datetime import datetime

# %%
from __future__ import division

# %%
tech_list = ['AAPL', 'GOOG','MSFT','AMZN']

# %%
end = datetime.now()

start = datetime(end.year-1,end.month,end.day)

# %%
for stock in tech_list:
    globals()[stock] = DataReader(stock,'yahoo',start,end)

# %%
import quandl as qdl

# %%
import fix_yahoo_finance as yf

# %%
tech_list = ['AAPL', 'GOOG','MSFT','AMZN']

# %%
end = datetime.now()

start = datetime(end.year-1,end.month,end.day)

# %%
from pandas_datareader import data as pdr
import fix_yahoo_finance

data = pdr.get_data_yahoo('BHP.AX',start='2017-04-23', end= '2017-05-24')
data2 = pdr.get_data_yahoo()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-472-0a4210bcf9da> in <module>()
#       3
#       4 data = pdr.get_data_yahoo('BHP.AX',start='2017-04-23', end= '2017-05-24')
# ----> 5 data2 = pdr.get_data_yahoo()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas_datareader\data.py in get_data_yahoo(*args, **kwargs)
#      68
#      69 def get_data_yahoo(*args, **kwargs):
# ---> 70     return YahooDailyReader(*args, **kwargs).read()
#      71
#      72
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas_datareader\base.py in read(self)
#     213             df = self._dl_mult_symbols(self.symbols.index)
#     214         else:
# --> 215             df = self._dl_mult_symbols(self.symbols)
#     216         return df
#     217
#
# ...

# %%
data.head()

# %%
cols = ['Date','Open','High','Low','Close','Volume','Adj Close']
data.reindex(columns=cols)

# %%
#download dataframe

data_dldf = pdr.get_data_yahoo("SPY",
                         start="2017-01-01", end="2017-04-30")

# download Panel
data_dlp = pdr.get_data_yahoo(["SPY","IWM"],
                         start="2017-01-01", end="2017-04-30")

# %%
data = pdr.get_data_yahoo('BHP.AX',start='2019-01-15', end= '2019-05-15')
Apple = pdr.get_data_yahoo('AAPL',start='2017-01-15',end= '2019-05-15')
Google = pdr.get_data_yahoo('GOOG',start='2017-01-15',end='2019-05-15')
Microsoft = pdr.get_data_yahoo('MSFT',start='2017-01-15',end='2019-05-15')
Amazon = pdr.get_data_yahoo('AMZN',start='2017-01-15',end='2019-05-15')

# %%
Apple.head()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2017-01-17  120.239998  118.220001  118.339996  120.000000  34439800.0
# 2017-01-18  120.500000  119.709999  120.000000  119.989998  23713000.0
# 2017-01-19  120.089996  119.370003  119.400002  119.779999  25597300.0
# 2017-01-20  120.449997  119.730003  120.449997  120.000000  32597900.0
# 2017-01-23  120.809998  119.769997  120.000000  120.080002  22050200.0
#
#              Adj Close  MA for 10 days  MA for 20 days  MA for 50 days  \
# Date
# 2017-01-17  115.412643             NaN             NaN             NaN
# 2017-01-18  115.403008             NaN             NaN             NaN
# 2017-01-19  115.201050             NaN             NaN             NaN
# 2017-01-20  115.412643             NaN             NaN             NaN
# 2017-01-23  115.489578             NaN             NaN             NaN
#
#             Daily Return
# Date
# 2017-01-17           NaN
# 2017-01-18     -0.000083
# ...

# %%
Google.head()
# Out:
#                   High         Low        Open       Close   Volume  \
# Date
# 2017-01-17  807.140015  800.369995  807.080017  804.609985  1355800
# 2017-01-18  806.205017  800.989990  805.809998  806.070007  1294400
# 2017-01-19  809.479980  801.799988  805.119995  802.174988   919300
# 2017-01-20  806.909973  801.690002  806.909973  805.020020  1670000
# 2017-01-23  820.869995  803.739990  807.250000  819.309998  1963600
#
#              Adj Close
# Date
# 2017-01-17  804.609985
# 2017-01-18  806.070007
# 2017-01-19  802.174988
# 2017-01-20  805.020020
# 2017-01-23  819.309998

# %%
Microsoft.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2017-01-17  62.700001  62.029999  62.680000  62.529999  20620400.0  59.646996
# 2017-01-18  62.700001  62.119999  62.669998  62.500000  19670100.0  59.618385
# 2017-01-19  62.980000  62.200001  62.240002  62.299999  18451700.0  59.427597
# 2017-01-20  62.820000  62.369999  62.669998  62.740002  30213500.0  59.847321
# 2017-01-23  63.119999  62.570000  62.700001  62.959999  23097600.0  60.057171

# %%
Amazon.head()
# Out:
#                  High         Low        Open       Close   Volume   Adj Close
# Date
# 2017-01-17  816.00000  803.440002  815.700012  809.719971  3659400  809.719971
# 2017-01-18  811.72998  804.270020  809.500000  807.479980  2354200  807.479980
# 2017-01-19  813.51001  807.320007  810.000000  809.039978  2540800  809.039978
# 2017-01-20  816.02002  806.260010  815.280029  808.330017  3376200  808.330017
# 2017-01-23  818.50000  805.080017  806.799988  817.880005  2797500  817.880005

# %%
Apple.describe()
# Out:
#              High         Low        Open       Close        Volume  \
# count  586.000000  586.000000  586.000000  586.000000  5.860000e+02
# mean   173.681502  170.715137  172.175734  172.264659  3.067324e+07
# std     25.202161   24.440344   24.819577   24.809740  1.338066e+07
# min    120.089996  118.220001  118.339996  119.779999  1.251390e+07
# 25%    154.885002  152.785000  154.000000  153.922497  2.156690e+07
# 50%    172.525002  169.659996  171.044998  171.065002  2.691210e+07
# 75%    189.552498  186.587505  188.172497  188.157501  3.576340e+07
# max    233.470001  229.779999  230.779999  232.070007  1.119850e+08
#
#         Adj Close  MA for 10 days  MA for 20 days  MA for 50 days  \
# count  586.000000      577.000000      577.000000      577.000000
# mean   169.103450      169.322608      169.322608      169.322608
# std     25.609351       25.018218       25.018218       25.018218
# min    115.201050      116.107040      116.107040      116.107040
# ...

# %%
Apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 586 entries, 2017-01-17 to 2019-05-15
# Data columns (total 10 columns):
# High              586 non-null float64
# Low               586 non-null float64
# Open              586 non-null float64
# Close             586 non-null float64
# Volume            586 non-null float64
# Adj Close         586 non-null float64
# MA for 10 days    577 non-null float64
# MA for 20 days    577 non-null float64
# MA for 50 days    577 non-null float64
# Daily Return      585 non-null float64
# dtypes: float64(10)
# memory usage: 50.4 KB

# %%
Apple['Adj Close'].plot(legend=True,figsize=(10,4))

# %%
Apple['Volume'].plot(legend=True,figsize=(10,4))

# %% [markdown]
# # outdated code
# ma_day = [10,20,50]
#
# for ma in ma_day:
#
#     column_name = "MA for %s days" %(str(ma))
#
#     Apple[column_name] = pd.rolling_mean(Apple['Adj Close'],ma)

# %%
ma_day = [10,20,50]

for ma in ma_day:
    
    column_name = "MA for %s days" %(str(ma))
    
    Apple[column_name] = Apple['Adj Close'].rolling(window=10,center=False).mean()

# %%
Apple_long_rolling = Apple.rolling(window=100).mean()
long_rolling.tail()
# Out:
#                   High       Low      Open     Close      Volume   Adj Close
# Date
# 2019-05-09  179.067701  175.5304  177.2162  177.4477  32623561.0  176.518844
# 2019-05-10  179.365401  175.8053  177.5004  177.7647  32628611.0  176.849232
# 2019-05-13  179.576700  176.0065  177.7230  177.9825  32760038.0  177.080295
# 2019-05-14  179.798400  176.2167  177.9333  178.2084  32786920.0  177.319631
# 2019-05-15  180.041400  176.4860  178.1360  178.5087  32561534.0  177.632947

# %%
Apple[['Close','MA for 10 days','MA for 20 days','MA for 50 days']].plot(subplots = False,figsize = (10,4))

# %%
Apple['Daily Return'] = Apple['Close'].pct_change()

Apple['Daily Return'].plot(figsize=(12,4),legend=True,linestyle='--',marker='o')

# %%
sns.distplot(Apple['Daily Return'].dropna(), bins = 100, color = 'purple')
# Out:
# C:\Users\kevin.b.wong\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
Apple['Daily Return'].hist(bins=100)

# %% [markdown]
# closing_df = DataReader(tech_list, 'yahoo', start,end)['Adj Close']

# %% [markdown]
# Apple = pdr.get_data_yahoo('AAPL',start='2017-01-15',end= '2019-05-15')
# Google = pdr.get_data_yahoo('GOOG',start='2017-01-15',end='2019-05-15')
# Microsoft = pdr.get_data_yahoo('MSFT',start='2017-01-15',end='2019-05-15')
# Amazon = pdr.get_data_yahoo('AMZN',start='2017-01-15',end='2019-05-15')

# %%
closing_df_test = DataReader(tech_list, 'yahoo', start='2017-01-15',end='2019-05-15')['Adj Close']

# %%
closing_df_test
# Out:
# Symbols           AAPL         AMZN         GOOG        MSFT
# Date
# 2017-01-17  115.412643   809.719971   804.609985   59.646996
# 2017-01-18  115.403008   807.479980   806.070007   59.618385
# 2017-01-19  115.201050   809.039978   802.174988   59.427597
# 2017-01-20  115.412643   808.330017   805.020020   59.847321
# 2017-01-23  115.489578   817.880005   819.309998   60.057171
# 2017-01-24  115.383789   822.440002   823.869995   60.591358
# 2017-01-25  117.220779   836.520020   835.669983   60.743980
# 2017-01-26  117.278488   839.150024   832.150024   61.306767
# 2017-01-27  117.288101   835.770020   823.309998   62.747162
# 2017-01-30  116.980324   830.380005   802.320007   62.127117
# 2017-01-31  116.711029   823.479980   796.789978   61.669258
# 2017-02-01  123.828148   832.349976   795.695007   60.648590
# 2017-02-02  123.616562   839.950012   798.530029   60.257488
# 2017-02-03  124.145538   810.200012   801.489990   60.743980
# ...

# %%
closing_df = DataReader(tech_list, 'yahoo', start,end)['Adj Close']

# %%
closing_df.head()
# Out:
# Symbols           AAPL         AMZN         GOOG       MSFT
# Date
# 2018-05-17  184.186310  1581.760010  1078.589966  94.643135
# 2018-05-18  183.516510  1574.369995  1066.359985  94.820259
# 2018-05-21  184.816711  1585.459961  1079.579956  96.040443
# 2018-05-22  184.353760  1581.400024  1069.729980  95.942047
# 2018-05-23  185.535767  1601.859985  1079.689941  97.083504

# %%
tech_rets = closing_df.pct_change()

# %%
tech_rets.head()
# Out:
# Symbols         AAPL      AMZN      GOOG      MSFT
# Date
# 2018-05-17       NaN       NaN       NaN       NaN
# 2018-05-18 -0.003637 -0.004672 -0.011339  0.001871
# 2018-05-21  0.007085  0.007044  0.012397  0.012868
# 2018-05-22 -0.002505 -0.002561 -0.009124 -0.001025
# 2018-05-23  0.006412  0.012938  0.009311  0.011897

# %%
sns.jointplot('GOOG','GOOG',tech_rets,kind = 'scatter',color='seagreen')
# Out:
# C:\Users\kevin.b.wong\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.jointplot('GOOG','MSFT',tech_rets,kind='scatter')
# Out:
# C:\Users\kevin.b.wong\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
tech_rets.head()
# Out:
# Symbols         AAPL      AMZN      GOOG      MSFT
# Date
# 2018-05-17       NaN       NaN       NaN       NaN
# 2018-05-18 -0.003637 -0.004672 -0.011339  0.001871
# 2018-05-21  0.007085  0.007044  0.012397  0.012868
# 2018-05-22 -0.002505 -0.002561 -0.009124 -0.001025
# 2018-05-23  0.006412  0.012938  0.009311  0.011897

# %%
sns.pairplot(tech_rets.dropna())

# %%
returns_fig = sns.PairGrid(tech_rets.dropna())

returns_fig.map_upper(plt.scatter,color='purple')

returns_fig.map_lower(sns.kdeplot,cmap='cool_d')

returns_fig.map_diag(plt.hist,bins = 30)
# Out:
# C:\Users\kevin.b.wong\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
returns_fig = sns.PairGrid(closing_df)

returns_fig.map_upper(plt.scatter,color='purple')

returns_fig.map_lower(sns.kdeplot,cmap='cool_d')

returns_fig.map_diag(plt.hist,bins = 30)
# Out:
# C:\Users\kevin.b.wong\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
import seaborn.regression

# %% [markdown]
# sns.heatmap()(tech_rets.dropna(),annot=True

# %%
import seaborn.regression 

(tech_rets.dropna(),annot=True)
# Out:
#   File "<ipython-input-500-2b1ff7fcc6db>", line 3
#     (tech_rets.dropna(),annot=True)
#                              ^
# SyntaxError: invalid syntax

# %%
#need alternative
from seaborn.linearmodels import corrplot

corrplot(tech_rets.dropna(), annot = True)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-501-e6fd07ea94de> in <module>()
#       1 #need alternative
# ----> 2 from seaborn.linearmodels import corrplot
#       3
#       4 corrplot(tech_rets.dropna(), annot = True)
#
# ImportError: cannot import name 'corrplot' from 'seaborn.linearmodels' (C:\Users\kevin.b.wong\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\linearmodels.py)

# %%
#corrplot has been deprecated
sns.corrplot(closing_df,annot=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-502-05c66f56dfb2> in <module>()
#       1 #corrplot has been deprecated
# ----> 2 sns.corrplot(closing_df,annot=True)
#
# AttributeError: module 'seaborn' has no attribute 'corrplot'

# %% [markdown]
# # Risk Analysis of a Stock

# %%
rets = tech_rets.dropna()

# %%
area = np.pi*20

plt.scatter(rets.mean(),rets.std(),s = area)

plt.xlabel('Expected Return')
plt.ylabel('Risk')

for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    plt.annotate(
        label, 
        xy = (x, y), xytext = (50, 50),
        textcoords = 'offset points', ha = 'right', va = 'bottom',
        arrowprops = dict(arrowstyle = '-', connectionstyle = 'arc3,rad=-0.3'))

# %%
sns.distplot(Apple['Daily Return'].dropna(),bins=100,color='purple')
# Out:
# C:\Users\kevin.b.wong\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
rets.head()
# Out:
# Symbols         AAPL      AMZN      GOOG      MSFT
# Date
# 2018-05-18 -0.003637 -0.004672 -0.011339  0.001871
# 2018-05-21  0.007085  0.007044  0.012397  0.012868
# 2018-05-22 -0.002505 -0.002561 -0.009124 -0.001025
# 2018-05-23  0.006412  0.012938  0.009311  0.011897
# 2018-05-24 -0.001115  0.000755 -0.000417 -0.003548

# %%
#value of risk is 2.9% of your investment -- everyday you'll lose 2.9% 95% of the times
rets['AAPL'].quantile(0.05)
# Out:
# -0.029789942308736383

# %%
days = 365

dt = 1/days

mu = rets.mean()['GOOG']

sigma = rets.std()['GOOG']

# %%
def stock_monte_carlo(start_price, days, mu, sigma):
    price = np.zeros(days)
    price[0] = start_price
    
    shock = np.zeros(days)
    drift = np.zeros(days)
    
    for x in range(1, days):
        
        shock[x] = np.random.normal(loc = mu*dt, scale = sigma * np.sqrt(dt))
        drift[x] = mu * dt
        price[x] = price[x-1] + (price[x-1] * (drift[x] + shock[x]))
        
    return price

# %%
GOOG.head()
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2018-05-17  1086.869995  1073.500000  1079.890015  1078.589966  1043800
# 2018-05-18  1069.939941  1060.680054  1061.859985  1066.359985  1565200
# 2018-05-21  1088.000000  1073.650024  1074.060059  1079.579956  1023200
# 2018-05-22  1086.589966  1066.689941  1083.560059  1069.729980  1090000
# 2018-05-23  1080.780029  1061.709961  1065.130005  1079.689941  1030000
#
#               Adj Close
# Date
# 2018-05-17  1078.589966
# 2018-05-18  1066.359985
# 2018-05-21  1079.579956
# 2018-05-22  1069.729980
# 2018-05-23  1079.689941

# %%
start_price = 10000

for run in range(100):
    plt.plot(stock_monte_carlo(start_price, days, mu, sigma))
    
plt.xlabel('Days')
plt.ylabel('Price')
plt.title('Monte Carlo Analysis for Google')
# Out:
# Text(0.5, 1.0, 'Monte Carlo Analysis for Google')

# %%
runs = 10000

simulations = np.zeros(runs)

for run in range(runs):
    simulations[run] = stock_monte_carlo(start_price, days, mu, sigma)[days-1]

# %%
q = np.percentile(simulations, 1)

plt.hist(simulations, bins = 200)

# Starting Price
plt.figtext(0.6, 0.8, s="Start price: $%.2f" %start_price)
# Mean ending price
plt.figtext(0.6, 0.7, "Mean final price: $%.2f" % simulations.mean())

# Variance of the price (within 99% confidence interval)
plt.figtext(0.6, 0.6, "VaR(0.99): $%.2f" % (start_price - q,))

# Display 1% quantile
plt.figtext(0.15, 0.6, "q(0.99): $%.2f" % q)

# Plot a line at the 1% quantile result
plt.axvline(x=q, linewidth=4, color='r')

# Title
plt.title(u"Final price distribution for Google Stock after %s days" % days, weight='bold');
